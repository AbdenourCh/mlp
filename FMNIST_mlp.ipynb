# %%
import torch
import numpy as np

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler



batch_size = 64
valid_size = 0.2

transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])

train_data = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', train=True,
                                   download=True, transform=transform)
test_data = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', train=False,
                                  download=True, transform=transform)

num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)


train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()


fig = plt.figure(figsize=(25,4))

Class = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle Boot']

for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    # print out the correct label for each image
    # .item() gets the value contained in a Tensor
    ax.set_title(str(Class[(labels[idx].item())]))

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the NN architecture
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()

        n_inputs = 28*28
        n_hidden_1 = 512
        n_hidden_2 = 512
        n_hidden_3 = 512
        n_outputs = 10


        self.fc1 = nn.Linear(n_inputs, n_hidden_1)
        self.fc2 = nn.Linear(n_hidden_1, n_hidden_2)
        self.fc3 = nn.Linear(n_hidden_2, n_hidden_3)
        self.fc4 = nn.Linear(n_hidden_3, n_outputs)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):

        x = x.view(-1, 28 * 28)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))
        x = self.dropout(x)
        x = self.fc4(x)
        
        return x

model = Network()
print(model)
# Out:
# Network(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=512, bias=True)
#   (fc4): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.003)

# %%
n_epochs = 50
valid_loss_min = np.Inf 

for epoch in range(n_epochs):
    train_loss = 0.0
    valid_loss = 0.0

    ###################
    # Train The Model #
    ###################

    model.train() 
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()*data.size(0)
        
    ######################
    # Validate The Model #
    ######################

    model.eval() 
    for data, target in valid_loader:
        output = model(data)
        loss = criterion(output, target)
        valid_loss += loss.item()*data.size(0)


    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.630223 	Validation Loss: 0.462272
# Validation loss decreased (inf --> 0.462272).  Saving model ...
# Epoch: 2 	Training Loss: 0.518410 	Validation Loss: 0.436605
# Validation loss decreased (0.462272 --> 0.436605).  Saving model ...
# Epoch: 3 	Training Loss: 0.489770 	Validation Loss: 0.423060
# Validation loss decreased (0.436605 --> 0.423060).  Saving model ...
# Epoch: 4 	Training Loss: 0.473026 	Validation Loss: 0.404073
# Validation loss decreased (0.423060 --> 0.404073).  Saving model ...
# Epoch: 5 	Training Loss: 0.456971 	Validation Loss: 0.405820
# Epoch: 6 	Training Loss: 0.457370 	Validation Loss: 0.426797
# Epoch: 7 	Training Loss: 0.442414 	Validation Loss: 0.404740
# Epoch: 8 	Training Loss: 0.432134 	Validation Loss: 0.402063
# Validation loss decreased (0.404073 --> 0.402063).  Saving model ...
# Epoch: 9 	Training Loss: 0.432342 	Validation Loss: 0.414842
# Epoch: 10 	Training Loss: 0.430406 	Validation Loss: 0.374282
# Validation loss decreased (0.402063 --> 0.374282).  Saving model ...
# Epoch: 11 	Training Loss: 0.423537 	Validation Loss: 0.377613
# Epoch: 12 	Training Loss: 0.412696 	Validation Loss: 0.401623
# Epoch: 13 	Training Loss: 0.413662 	Validation Loss: 0.375720
# Epoch: 14 	Training Loss: 0.417345 	Validation Loss: 0.428730
# Epoch: 15 	Training Loss: 0.418934 	Validation Loss: 0.390267
# Epoch: 16 	Training Loss: 0.417533 	Validation Loss: 0.388145
# Epoch: 17 	Training Loss: 0.406948 	Validation Loss: 0.391161
# Epoch: 18 	Training Loss: 0.410098 	Validation Loss: 0.403306
# Epoch: 19 	Training Loss: 0.399971 	Validation Loss: 0.369895
# Validation loss decreased (0.374282 --> 0.369895).  Saving model ...
# Epoch: 20 	Training Loss: 0.394410 	Validation Loss: 0.385683
# Epoch: 21 	Training Loss: 0.404679 	Validation Loss: 0.384813
# Epoch: 22 	Training Loss: 0.394968 	Validation Loss: 0.368778
# Validation loss decreased (0.369895 --> 0.368778).  Saving model ...
# Epoch: 23 	Training Loss: 0.389873 	Validation Loss: 0.372807
# Epoch: 24 	Training Loss: 0.392412 	Validation Loss: 0.377782
# Epoch: 25 	Training Loss: 0.393902 	Validation Loss: 0.382755
# Epoch: 26 	Training Loss: 0.393945 	Validation Loss: 0.385245
# Epoch: 27 	Training Loss: 0.390767 	Validation Loss: 0.398344
# Epoch: 28 	Training Loss: 0.389037 	Validation Loss: 0.382662
# Epoch: 29 	Training Loss: 0.396313 	Validation Loss: 0.366598
# Validation loss decreased (0.368778 --> 0.366598).  Saving model ...
# Epoch: 30 	Training Loss: 0.381796 	Validation Loss: 0.388558
# Epoch: 31 	Training Loss: 0.389017 	Validation Loss: 0.376689
# Epoch: 32 	Training Loss: 0.387469 	Validation Loss: 0.364693
# Validation loss decreased (0.366598 --> 0.364693).  Saving model ...
# Epoch: 33 	Training Loss: 0.383111 	Validation Loss: 0.385830
# Epoch: 34 	Training Loss: 0.393614 	Validation Loss: 0.400256
# Epoch: 35 	Training Loss: 0.377234 	Validation Loss: 0.361850
# Validation loss decreased (0.364693 --> 0.361850).  Saving model ...
# Epoch: 36 	Training Loss: 0.380763 	Validation Loss: 0.402903
# Epoch: 37 	Training Loss: 0.397324 	Validation Loss: 0.386384
# Epoch: 38 	Training Loss: 0.383898 	Validation Loss: 0.378044
# Epoch: 39 	Training Loss: 0.382158 	Validation Loss: 0.363237
# Epoch: 40 	Training Loss: 0.365285 	Validation Loss: 0.377192
# Epoch: 41 	Training Loss: 0.372188 	Validation Loss: 0.380816
# Epoch: 42 	Training Loss: 0.366620 	Validation Loss: 0.385608
# Epoch: 43 	Training Loss: 0.389860 	Validation Loss: 0.396078
# Epoch: 44 	Training Loss: 0.370226 	Validation Loss: 0.385723
# Epoch: 45 	Training Loss: 0.367923 	Validation Loss: 0.400082
# Epoch: 46 	Training Loss: 0.367889 	Validation Loss: 0.432518
# Epoch: 47 	Training Loss: 0.368310 	Validation Loss: 0.403731
# Epoch: 48 	Training Loss: 0.378274 	Validation Loss: 0.411711
# Epoch: 49 	Training Loss: 0.375442 	Validation Loss: 0.380515
# Epoch: 50 	Training Loss: 0.369778 	Validation Loss: 0.394648

# %%
model.load_state_dict(torch.load('model.pt'))
# Out:
# <All keys matched successfully>

# %%
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval() 

for data, target in test_loader:

    output = model(data)
    loss = criterion(output, target)
    test_loss += loss.item()*data.size(0)
    _, pred = torch.max(output, 1)
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))


    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %11s: %5d%% (%2d/%2d)' % (
            str(Class[i]), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.392084
#
# Test Accuracy of T-shirt/top:    77% (775/1000)
# Test Accuracy of     Trouser:    96% (963/1000)
# Test Accuracy of    Pullover:    77% (775/1000)
# Test Accuracy of       Dress:    91% (914/1000)
# Test Accuracy of        Coat:    76% (761/1000)
# Test Accuracy of      Sandal:    94% (944/1000)
# Test Accuracy of       Shirt:    69% (695/1000)
# Test Accuracy of     Sneaker:    92% (921/1000)
# Test Accuracy of         Bag:    96% (961/1000)
# Test Accuracy of  Ankle Boot:    95% (959/1000)
#
# Test Accuracy (Overall): 86% (8668/10000)

# %%
dataiter = iter(test_loader)
images, labels = dataiter.next()

output = model(images)
_, preds = torch.max(output, 1)
images = images.numpy()

fig = plt.figure(figsize=(25, 4))

print(len(images))

for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(Class[preds[idx].item()]), str(Class[labels[idx].item()])),
                 color=("green" if preds[idx]==labels[idx] else "red"))
# Out:
# 64
